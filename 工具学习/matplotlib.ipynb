# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Basic Graph

# %%
fig = plt.figure()  # an empty figure with no Axes
fig, ax = plt.subplots()  # a figure with a single Axes
fig, axs = plt.subplots(2, 2)  # a figure with a 2x2 grid of Axes

# %%
fig, ax = plt.subplots() #返回一个figure和一个axes
ax.plot([1,2,3,4], [1,4,2,3])
ax.plot([9,8,5,6],[5,6,3,5])

# %%
plt.plot([1, 2, 3, 4], [1, 4, 2, 3])  # Matplotlib plot.

# %%
plt.imshow(plt.imread('./anatomy.webp'))
#print(help(plt.imshow))

# %%
# do (OO-style) 面向对象的风格，
#the pyplot API is generally less-flexible than the object-oriented API. 
#Most of the function calls you see here can also be called as methods from an Axes object. 
#We recommend browsing the tutorials and examples to see how this works.
x = np.linspace(0,2, 100)

# Note that even in the OO-style, we use `.pyplot.figure` to create the figure.
fig, ax = plt.subplots()  # Create a figure and an axes.
ax.plot(x, x, label='linear')  # Plot some data on the axes.
ax.plot(x, x**2, label='quadratic')  # Plot more data on the axes...
ax.plot(x, x**3, label='cubic')  # ... and some more.
ax.set_xlabel('x label')  # Add an x-label to the axes.
ax.set_ylabel('y label')  # Add a y-label to the axes.
ax.set_title("Simple Plot")  # Add a title to the axes.

ax.legend()  # Add a legend. 图例

# %%
# 直接调工具包的方法，简单快捷
x = np.linspace(-2 ,2 , 100)
y_sin = np.sin(x)
y_cos = np.cos(x)
y_tan = np.tan(x)
plt.plot(x, x, label='liner')
plt.plot(x, y_sin, label='sin')
plt.plot(x, y_cos, label='cos', color='green')
plt.grid()
plt.legend()
plt.title("Simple Plot")
#help(plt.plot)
# Out:
# Text(0.5, 1.0, 'Simple Plot')

# %%
x = np.linspace(0,2, 100)
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x, x**4, label='cubic')  # ... and some more.
ax.set_title("call ax") #
# 不再显示图像，推测是一个单元格内plt代码执行完后会释放figure
#fig.show()
# Out:
# Text(0.5, 1.0, 'call ax')

# %%
data1, data2, data3, data4 = np.random.randn(4, 100)
print(data1)
fig, ax = plt.subplots(1,1)
ax.plot(data1, data2)
# Out:
# [ 1.01240427 -0.81755557 -0.03508544 -0.75140926  0.60503534 -0.03142768
#  -0.12246492  1.10294371  1.35088384 -0.39145476  0.07760893  0.77386251
#   0.70676718  0.38706059 -0.55300377 -0.37594259 -1.73420828  0.33653563
#   0.02805733 -0.10166459  0.13853097  1.33459096 -1.35391821 -1.83899424
#   2.4452504   1.37693754 -0.70044346 -1.20381257 -1.2020282  -0.21461509
#   1.86824851  0.36399307  1.00580352  1.3686826  -0.10997613 -1.9394487
#  -0.66166368  1.03801048 -0.34820055 -1.6826983  -0.135705    0.14042564
#  -0.85605437 -1.36018015  0.19053225  0.3330258  -1.08196031  1.08532621
#   0.69084847  0.63370393 -1.62031482  1.01865895  0.17528272  1.39747819
#  -0.14620583 -0.25299872  0.18991918  0.6450748  -0.53205854 -0.22756235
#  -1.56758419  0.65856255 -1.09657086 -0.61456819  0.51046195  0.92577243
#   2.13850382  1.11792355 -0.10335366 -1.73292337  0.14149778 -1.86046946
#  -0.47903359  1.82709698 -1.82347113  1.20374084  0.10250012 -0.25935817
# ...

# %%
def my_plotter(ax, data1, data2, param_dict):
    """
    A helper function to make a graph

    Parameters
    ----------
    ax : Axes
        The axes to draw to

    data1 : array
       The x data

    data2 : array
       The y data

    param_dict : dict
       Dictionary of kwargs to pass to ax.plot

    Returns
    -------
    out : list
        list of artists added
    """
    out = ax.plot(data1, data2, **param_dict) #字典里可以传入各种样式说明
    return out

# %%
data1, data2, data3, data4 = np.random.randn(4, 100)
fig, ax = plt.subplots(1, 1)
my_plotter(ax, data1, data2, {'marker': '+'})#关键点用+来mark

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
my_plotter(ax1, data1, data2, {'marker': 'x','color':'r'})
my_plotter(ax2, data3, data4, {'marker': 'o', 'linestyle':'--'})

# %%
## 混合样式字典
# red dashes, blue squares and green triangles
t = np.arange(0., 5., 0.2)
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %%
# /画图时传入字典数据，传键即可

data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()

# %%
plt.scatter(data['a'], data['b'], c=data['c'], s=data['d'])
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()

# %%
x = np.linspace(-0.01, 0.01, 100)
#print(data)
y = np.sin(1.0 / x)
z = np.sin(x*1000)
plt.grid()
#plt.plot(x, y , color='r')
plt.plot(x, z)

# %%
x = np.linspace(-10, 10, 900)
y = np.sin(x) * x
plt.grid()
plt.plot(x, y, 'r')

# %%
x = np.linspace(-1*np.pi*5, np.pi*5, 1200)
y = np.sin(x)
plt.grid()
plt.plot(x, y, 'g')

# %%
# 定位不同子图

def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure()
plt.subplot(211)
plt.plot(t1, f(t1), 'bo')
plt.plot(t2, f(t2), 'k')

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(1)                # the first figure
plt.subplot(211)             # the first subplot in the first figure
plt.plot([1, 2, 3]) #只给出1维的话会自动给x轴补充[0, n-1]
plt.title('Easy as 1, 2, 3') # subplot 211 title
plt.subplot(212)             # the second subplot in the first figure
plt.plot([4, 5, 6])


plt.figure(2)                # a second figure
plt.plot([4, 5, 6])          # creates a subplot(111) by default

#再选中fig1中的212区时，会导致之前的被清空，从队列之后再重新画出，所以fig跑到下面来了
plt.figure(1)                # figure 1 current; subplot(212) still current
#plt.subplot(212)             # make subplot(211) in figure1 current


plt.show()

# %%
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000) #np.random.randn Return a sample (or samples) from the "standard normal" distribution. so x~N(mu, sigma)
#help(np.random.randn)
x = np.random.randn(10000)
# the histogram of the data
n, bins, patches = plt.hist(x, 50, density=1, facecolor='g', alpha=0.75)
help(plt.hist)

plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(-3, .25, r'$\mu=0,\ \sigma=1$') #支持markdown语法
plt.axis([-4, 4, 0, 0.5])
plt.grid(True)
plt.show()
# Out:
# Help on function hist in module matplotlib.pyplot:
#
# hist(x, bins=None, range=None, density=False, weights=None, cumulative=False, bottom=None, histtype='bar', align='mid', orientation='vertical', rwidth=None, log=False, color=None, label=None, stacked=False, *, data=None, **kwargs)
#     Plot a histogram.
#
#     Compute and draw the histogram of *x*.  The return value is a tuple
#     (*n*, *bins*, *patches*) or ([*n0*, *n1*, ...], *bins*, [*patches0*,
#     *patches1*, ...]) if the input contains multiple data.  See the
#     documentation of the *weights* parameter to draw a histogram of
#     already-binned data.
#
#     Multiple data can be provided via *x* as a list of datasets
#     of potentially different length ([*x0*, *x1*, ...]), or as
#     a 2-D ndarray in which each column is a dataset.  Note that
#     the ndarray form is transposed relative to the list form.
#
#     Masked arrays are not supported.
#
# ...

# %%
# Fixing random state for reproducibility
np.random.seed(19680801)

# make up some data in the open interval (0, 1)
y = np.random.normal(loc=0.5, scale=0.4, size=1000)
y = y[(y > 0) & (y < 1)]
y.sort()
x = np.arange(len(y))

# plot with various axes scales
plt.figure()

# linear
plt.subplot(221)
plt.plot(x, y)
plt.yscale('linear')
plt.title('linear')
plt.grid(True)

# log
plt.subplot(222)
plt.plot(x, y)
plt.yscale('log')
plt.title('log')
plt.grid(True)

# symmetric log
plt.subplot(223)
plt.plot(x, y - y.mean())
plt.yscale('symlog', linthresh=0.01)
plt.title('symlog')
plt.grid(True)

# logit
plt.subplot(224)
plt.plot(x, y)
plt.yscale('logit')
plt.title('logit')
plt.grid(True)
# Adjust the subplot layout, because the logit one may take more space
# than usual, due to y-tick labels like "1 - 10^{-3}"
plt.subplots_adjust(top=0.92, bottom=0.08, left=0.10, right=0.95, hspace=0.25,
                    wspace=0.35)

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator
import numpy as np
fig, ax = plt.subplots(subplot_kw={"projection": "3d"}, figsize=(8,8)) #设置画布大小 800*800

u = np.linspace(-1, 1, 50)
x,y = np.meshgrid(u, u)

z = np.sqrt(x**2 + y**2)
ax.plot_surface(x,y, z)
ax.set_xlabel('x')  # Add an x-label to the axes.
ax.set_ylabel('y')  # Add a y-label to the axes.
ax.set_zlabel('z')  # Add a y-label to the axes.
plt.show()

# %%
#等高线绘制

x = np.linspace(-1, 1, 100)
y = np.linspace(-1, 1, 100)
X,Y = np.meshgrid(x, y)
Z = X**2 + Y**2

plt.subplot()
c = plt.contour(X, Y ,Z,8 )
plt.clabel(c,inline=True,fontsize=15)
# Out:
# <a list of 8 text.Text objects>

# %%
import mpl_toolkits.axisartist as axisartist
x = np.linspace(-2*np.pi , 2*np.pi, 400)
y = np.sin(x)

fig = plt.figure(figsize=(8,8)) 
ax = axisartist.Subplot(fig, 111)
fig.add_axes(ax)
#ax.axis[:].set_visible(False)
ax.axis['x'] = ax.new_floating_axis(0, 0)
ax.axis['y'] = ax.new_floating_axis(1, 0) #添加到第1维度，位置为0处

ax.axis['x'].set_axis_direction('bottom') #刻度位置
#ax.axis['x'].set_visible(True)
ax.axis['y'].set_axis_direction('left')
#ax.axis['y'].set_visible(True)

#箭头
ax.axis["x"].set_axisline_style("->", size = 10.0)
ax.axis["y"].set_axisline_style("-|>", size = 10.0)

ax.set_yticks([-1, 0, 1])
#ax.set_xticks([-1*np.pi, 0, np.pi])
ax.plot(x, y)
plt.show()

help(ax.axis['x'].set_axisline_style)
# Out:
# Help on method set_axisline_style in module mpl_toolkits.axisartist.axis_artist:
#
# set_axisline_style(axisline_style=None, **kwargs) method of mpl_toolkits.axisartist.axis_artist.AxisArtist instance
#     Set the axisline style.
#
#     The new style is completely defined by the passed attributes. Existing
#     style attributes are forgotten.
#
#     Parameters
#     ----------
#     axisline_style : str or None
#         The line style, e.g. '->', optionally followed by a comma-separated
#         list of attributes. Alternatively, the attributes can be provided
#         as keywords.
#
#         If *None* this returns a string containing the available styles.
#
#     Examples
#     --------
#     The following two commands are equal:
#     >>> set_axisline_style("->,size=1.5")
#     >>> set_axisline_style("->", size=1.5)

# %%
# 一次打印多张图片
# 按照子图的坐标位置打印


# 显示原始图像和增强后的图像
import tensorflow as tf
from matplotlib import pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np

mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)

image_gen_train = ImageDataGenerator( #Generate batches of tensor image data with real-time data augmentation.
    rescale=1. / 255,
    rotation_range=45,
    width_shift_range=.15,
    height_shift_range=.15,
    horizontal_flip=False,
    zoom_range=0.5
)

image_gen_train.fit(x_train) #Fits the data generator to some sample data.
print("xtrain",x_train.shape)

x_train_subset1 = np.squeeze(x_train[:24])
print("xtrain_subset1",x_train_subset1.shape)
print("xtrain",x_train.shape)

x_train_subset2 = x_train[:24]  # 一次显示24张图片
print("xtrain_subset2",x_train_subset2.shape)

fig = plt.figure(figsize=(20, 4))
plt.set_cmap('gray')
# 显示原始图片
for i in range(0, len(x_train_subset1)):
    ax = fig.add_subplot(2, 12, i + 1) # 2行12列，一行摆满自动换行i+1
    ax.imshow(x_train_subset1[i])
fig.suptitle('Subset of Original Training Images', fontsize=20)
plt.show()

# 显示增强后的图片
fig = plt.figure(figsize=(20, 4))
for x_batch in image_gen_train.flow(x_train_subset2, batch_size=24, shuffle=False):
    for i in range(0, 24):
        ax = fig.add_subplot(2, 12, i + 1)
        ax.imshow(np.squeeze(x_batch[i]))
    fig.suptitle('Augmented Images', fontsize=20)
    plt.show()
    break;
# Out:
# xtrain (60000, 28, 28, 1)
# xtrain_subset1 (24, 28, 28)
# xtrain (60000, 28, 28, 1)
# xtrain_subset2 (24, 28, 28, 1)
