# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Basic Graph

# %%
fig = plt.figure()  # an empty figure with no Axes
fig, ax = plt.subplots()  # a figure with a single Axes
fig, axs = plt.subplots(2, 2)  # a figure with a 2x2 grid of Axes

# %%
fig, ax = plt.subplots() #返回一个figure和一个
ax.plot([1,2,3,4], [1,4,2,3])
ax.plot([9,8,5,6],[5,6,3,5])

# %%
plt.plot([1, 2, 3, 4], [1, 4, 2, 3])  # Matplotlib plot.

# %%
plt.imshow(plt.imread('./anatomy.webp'))
#print(help(plt.imshow))

# %%
# do (OO-style) 面向对象的风格，
#the pyplot API is generally less-flexible than the object-oriented API. 
#Most of the function calls you see here can also be called as methods from an Axes object. 
#We recommend browsing the tutorials and examples to see how this works.
x = np.linspace(0,2, 100)

# Note that even in the OO-style, we use `.pyplot.figure` to create the figure.
fig, ax = plt.subplots()  # Create a figure and an axes.
ax.plot(x, x, label='linear')  # Plot some data on the axes.
ax.plot(x, x**2, label='quadratic')  # Plot more data on the axes...
ax.plot(x, x**3, label='cubic')  # ... and some more.
ax.set_xlabel('x label')  # Add an x-label to the axes.
ax.set_ylabel('y label')  # Add a y-label to the axes.
ax.set_title("Simple Plot")  # Add a title to the axes.

ax.legend()  # Add a legend. 图例

# %%
# 直接调工具包的方法，简单快捷
x = np.linspace(-2 ,2 , 100)
y_sin = np.sin(x)
y_cos = np.cos(x)
y_tan = np.tan(x)
plt.plot(x, x, label='liner')
plt.plot(x, y_sin, label='sin')
plt.plot(x, y_cos, label='cos', color='green')
plt.grid()
plt.legend()
plt.title("Simple Plot")
#help(plt.plot)
# Out:
# Text(0.5, 1.0, 'Simple Plot')

# %%
x = np.linspace(0,2, 100)
ax.plot(x, x**4, label='cubic')  # ... and some more.
ax.set_title("call ax") #
# 不再显示图像，推测是一个单元格内plt代码执行完后会释放figure
# Out:
# Text(0.5, 1.0, 'call ax')

# %%
data1, data2, data3, data4 = np.random.randn(4, 100)
print(data1)
fig, ax = plt.subplots(1, 1)
ax.plot(data1, data2)
# Out:
# [ 0.4652108   1.20221566 -0.58179585 -0.16707265 -0.27992761 -1.02011067
#  -1.16873053 -2.53644349 -1.66583874  1.60002795 -0.4468563   0.15466637
#  -0.91671401  0.48981463 -1.60633149  1.17934991 -1.36462766  0.54187676
#   0.45660327 -0.54571767  2.27492369  2.00395864 -1.52422704 -1.31833923
#   0.27681412  0.21001851 -0.96112912 -0.15222589  0.37253894  0.88277614
#  -0.01489783  0.39237154  1.13594746  0.09062117 -0.07526488 -0.40687249
#   1.27356755  1.37944616 -0.45671747  0.31658966 -1.37324354 -0.60527793
#  -1.06026534 -0.14584034  0.5525917  -1.07904493  0.1200581   0.03640901
#   0.73769567  1.98838239 -0.38644364 -1.33086056  1.45466278 -0.54501041
#  -0.52394241 -0.59573111 -0.19606611  2.29208143  0.94116574 -0.37973939
#  -0.53264542  0.51495958  0.62267902  0.32912963 -0.29317547 -1.35191709
#   0.37636935 -0.92409714 -0.23966538 -1.26013054 -0.92468105  1.42678905
#   1.3306651   1.12421372  0.48963402  2.17834773 -1.09180684 -1.43867294
#  -0.39909517 -0.32896332  0.01651736  1.12335503  1.08551634 -0.77647344
#  -0.15761697  0.31363372 -1.46479613 -1.95824428 -0.50059858 -1.48764007
#   0.71307068 -0.06641146  3.65489626 -0.62154056 -0.49137427  1.61252516
#  -0.08918775  0.3537911   0.0526917  -0.59787005]

# %%
def my_plotter(ax, data1, data2, param_dict):
    """
    A helper function to make a graph

    Parameters
    ----------
    ax : Axes
        The axes to draw to

    data1 : array
       The x data

    data2 : array
       The y data

    param_dict : dict
       Dictionary of kwargs to pass to ax.plot

    Returns
    -------
    out : list
        list of artists added
    """
    out = ax.plot(data1, data2, **param_dict) #字典里可以传入各种样式说明
    return out

# %%
data1, data2, data3, data4 = np.random.randn(4, 100)
fig, ax = plt.subplots(1, 1)
my_plotter(ax, data1, data2, {'marker': '+'})#关键点用+来mark

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
my_plotter(ax1, data1, data2, {'marker': 'x','color':'r'})
my_plotter(ax2, data3, data4, {'marker': 'o', 'linestyle':'--'})

# %%
## 混合样式字典
# red dashes, blue squares and green triangles
t = np.arange(0., 5., 0.2)
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %%
# /画图时传入字典数据，传键即可

data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()

# %%
plt.scatter(data['a'], data['b'], c=data['c'], s=data['d'])
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()

# %%
x = np.linspace(-0.01, 0.01, 100)
#print(data)
y = np.sin(1.0 / x)
z = np.sin(x*1000)
plt.grid()
#plt.plot(x, y , color='r')
plt.plot(x, z)

# %%
x = np.linspace(-10, 10, 900)
y = np.sin(x) * x
plt.grid()
plt.plot(x, y, 'r')

# %%
x = np.linspace(-1*np.pi*5, np.pi*5, 1200)
y = np.sin(x)
plt.grid()
plt.plot(x, y, 'g')

# %%
# 定位不同子图

def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure()
plt.subplot(211)
plt.plot(t1, f(t1), 'bo')
plt.plot(t2, f(t2), 'k')

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(1)                # the first figure
plt.subplot(211)             # the first subplot in the first figure
plt.plot([1, 2, 3]) #只给出1维的话会自动给x轴补充[0, n-1]
plt.title('Easy as 1, 2, 3') # subplot 211 title
plt.subplot(212)             # the second subplot in the first figure
plt.plot([4, 5, 6])


plt.figure(2)                # a second figure
plt.plot([4, 5, 6])          # creates a subplot(111) by default

#再选中fig1中的212区时，会导致之前的被清空，从队列之后再重新画出，所以fig跑到下面来了
plt.figure(1)                # figure 1 current; subplot(212) still current
#plt.subplot(212)             # make subplot(211) in figure1 current


plt.show()

# %%
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000) #np.random.randn Return a sample (or samples) from the "standard normal" distribution. so x~N(mu, sigma)
#help(np.random.randn)
x = np.random.randn(10000)
# the histogram of the data
n, bins, patches = plt.hist(x, 50, density=1, facecolor='g', alpha=0.75)
#help(plt.axis)

plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(-3, .25, r'$\mu=0,\ \sigma=1$') #支持markdown语法
plt.axis([-4, 4, 0, 0.5])
plt.grid(True)
plt.show()

# %%
# Fixing random state for reproducibility
np.random.seed(19680801)

# make up some data in the open interval (0, 1)
y = np.random.normal(loc=0.5, scale=0.4, size=1000)
y = y[(y > 0) & (y < 1)]
y.sort()
x = np.arange(len(y))

# plot with various axes scales
plt.figure()

# linear
plt.subplot(221)
plt.plot(x, y)
plt.yscale('linear')
plt.title('linear')
plt.grid(True)

# log
plt.subplot(222)
plt.plot(x, y)
plt.yscale('log')
plt.title('log')
plt.grid(True)

# symmetric log
plt.subplot(223)
plt.plot(x, y - y.mean())
plt.yscale('symlog', linthresh=0.01)
plt.title('symlog')
plt.grid(True)

# logit
plt.subplot(224)
plt.plot(x, y)
plt.yscale('logit')
plt.title('logit')
plt.grid(True)
# Adjust the subplot layout, because the logit one may take more space
# than usual, due to y-tick labels like "1 - 10^{-3}"
plt.subplots_adjust(top=0.92, bottom=0.08, left=0.10, right=0.95, hspace=0.25,
                    wspace=0.35)

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator
import numpy as np
fig, ax = plt.subplots(subplot_kw={"projection": "3d"}, figsize=(8,8)) #设置画布大小 800*800

u = np.linspace(-1, 1, 50)
x,y = np.meshgrid(u, u)

z = np.sqrt(x**2 + y**2)
ax.plot_surface(x,y, z)
ax.set_xlabel('x')  # Add an x-label to the axes.
ax.set_ylabel('y')  # Add a y-label to the axes.
ax.set_zlabel('z')  # Add a y-label to the axes.
plt.show()
